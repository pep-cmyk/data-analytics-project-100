# %%
import requests as r

# %%
visits_data = r.get("https://data-charts-api.hexlet.app/visits?begin=2023-03-01&end=2023-09-01")
regs_data = r.get("https://data-charts-api.hexlet.app/registrations?begin=2023-03-01&end=2023-09-01")
